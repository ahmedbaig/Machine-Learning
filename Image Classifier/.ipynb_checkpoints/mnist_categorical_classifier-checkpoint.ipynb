# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import numpy as np
import time
from tensorflow.keras.callbacks import TensorBoard
tf.Session(config=tf.ConfigProto(log_device_placement=True))
tf.__version__
# Out:
# '1.10.0'

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()  
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
NAME = f"mnist-model-{int(time.time())}"
tensorboard = TensorBoard(f"log_dir/{NAME}")
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))
model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=['accuracy']
    )
model.fit(x_train, y_train, epochs=10, callbacks=[tensorboard])
model.save(os.path.join('model', NAME))
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 7s 120us/step - loss: 0.2621 - acc: 0.9221
# Epoch 2/10
# 60000/60000 [==============================] - 7s 115us/step - loss: 0.1076 - acc: 0.9662
# Epoch 3/10
# 60000/60000 [==============================] - ETA: 0s - loss: 0.0736 - acc: 0.977 - 7s 116us/step - loss: 0.0736 - acc: 0.9773
# Epoch 4/10
# 60000/60000 [==============================] - 7s 120us/step - loss: 0.0539 - acc: 0.9830
# Epoch 5/10
# 60000/60000 [==============================] - 7s 118us/step - loss: 0.0408 - acc: 0.9865
# Epoch 6/10
# 60000/60000 [==============================] - 7s 124us/step - loss: 0.0321 - acc: 0.9892
# Epoch 7/10
# 60000/60000 [==============================] - 7s 119us/step - loss: 0.0240 - acc: 0.9922
# Epoch 8/10
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.0202 - acc: 0.9932
# Epoch 9/10
# 60000/60000 [==============================] - 7s 121us/step - loss: 0.0183 - acc: 0.9935
# Epoch 10/10
# 60000/60000 [==============================] - 7s 118us/step - loss: 0.0141 - acc: 0.9952

# %%
val_acc, val_loss = model.evaluate(x_test, y_test)
print(val_acc*100, val_loss*100)
# Out:
# 10000/10000 [==============================] - 1s 77us/step
# 11.743274315505769 97.42

# %%
new_model = tf.keras.models.load_model(os.path.join('model', "mnist-model-1560680303"))
prediction = new_model.predict([x_test])
print(len(prediction))
iteration = 0
for predict in prediction[:10]: 
    index = 0
    for label in y_test[:10]: 
        if np.argmax(predict) == label:
            iteration+=1
            plt.title(f"Prediction from model: {np.argmax(predict)}, Iteration for image: {iteration}") 
            plt.imshow(x_test[index])
            plt.show()
        index+=1
# Out:
# 10000

# %%
import cv2
img = np.zeros((512,512,3), np.uint8)
image = cv2.rectangle(img,(250,300),(400,400),(0,255,0),3)
plt.imshow(image)
cv2.waitKey()
#image =
